# %%
data = 'C:/Users/srini/Downloads/dataset'

# %%
import os
os.listdir(data)
# Out:
# ['england_premier_league_squad_defensive_actions_22.csv',
#  'england_premier_league_squad_goalkeeping_22.csv',
#  'england_premier_league_squad_goal_shot_creation_22.csv',
#  'england_premier_league_squad_passing_stats_22.csv',
#  'england_premier_league_squad_possession_22.csv',
#  'england_premier_league_squad_shooting_22.csv',
#  'england_premier_league_stats_22.csv',
#  'england_premier_league_table_22.csv']

# %%
project_name = "EPL Analysis"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
defensive = pd.read_csv(data+'/england_premier_league_squad_defensive_actions_22.csv',sep=';');
goalkeeping = pd.read_csv(data+'/england_premier_league_squad_goalkeeping_22.csv',sep=';')
goal_shot = pd.read_csv(data+'/england_premier_league_squad_goal_shot_creation_22.csv',sep=';')
passes = pd.read_csv(data+'/england_premier_league_squad_passing_stats_22.csv',sep=';')
possession = pd.read_csv(data+'/england_premier_league_squad_possession_22.csv',sep=';')
shooting = pd.read_csv(data+'/england_premier_league_squad_shooting_22.csv',sep=';')
stats = pd.read_csv(data+'/england_premier_league_stats_22.csv',sep=';')
table = pd.read_csv(data+'/england_premier_league_table_22.csv',sep=';')

# %%
defensive.head()
# Out:
#          Squad  NPl  TotTkl  TotTklW  Def3rdTck  Mid3rdTck  Att3rdTck  \
# 0      Arsenal   27     573      350        262        211        100
# 1  Aston Villa   31     686      398        347        258         81
# 2    Brentford   29     693      398        339        254        100
# 3     Brighton   26     722      452        323        280        119
# 4      Burnley   23     629      361        299        250         80
#
#    TklWvsDrib  AttTckvsDrib  TklWvsDribRt  ...  Mid3rdPres  Att3rdPres  \
# 0         183           421          43.5  ...        1910        1464
# 1         250           594          42.1  ...        2402        1227
# 2         257           602          42.7  ...        2351        1223
# 3         242           569          42.5  ...        2280        1594
# 4         221           553          40.0  ...        2362        1395
#
#    TotBlocBal  ShBlocBall  ShSvBloc  PassBlock  Int  TklpInt  Clear  Err
# ...

# %%
goalkeeping.head()
# Out:
#          Squad  # Pl  MP  GATot  GA90  SoTA  Saves  SaveRt   W   D   L  CS  \
# 0      Arsenal     2  38     48  1.26   141     93    69.5  22   3  13  13
# 1  Aston Villa     3  38     54  1.42   145     96    65.5  13   6  19  11
# 2    Brentford     3  38     56  1.47   173    123    70.5  13   7  18   9
# 3     Brighton     2  38     44  1.16   145    103    71.7  12  15  11  11
# 4      Burnley     2  38     53  1.39   172    123    72.1   7  14  17   9
#
#    CSRt  PKatt  PKA  PKsv  PKm  SavPenRt
# 0  34.2      6    5     0    1       0.0
# 1  28.9      6    4     1    1      20.0
# 2  23.7      5    5     0    0       0.0
# 3  28.9      4    3     0    1       0.0
# 4  23.7      5    5     0    0       0.0

# %%
goal_shot.head()
# Out:
#          Squad  NPl  SCAT  SCA90  PassLiveSCA  PassDeadSCA  DribSCA  ShSCA  \
# 0      Arsenal   27   921  24.24          689           65       54     53
# 1  Aston Villa   31   725  19.08          527           73       33     34
# 2    Brentford   29   640  16.84          435           83       29     41
# 3     Brighton   26   748  19.68          534           77       46     42
# 4      Burnley   23   579  15.24          385           77       23     34
#
#    FldSCA  DefSCA  GCAT  GCA90  PassLiveGCA  PassDeadGCA  DribGCA  ShGCA  \
# 0      39      21    88   2.32           60            9        1     10
# 1      46      12    82   2.16           55            8        7      8
# 2      40      12    74   1.95           45            7        3      8
# 3      34      15    64   1.68           43            8        3      5
# 4      49      11    56   1.47           35            8        5      3
#
#    FldGCA  DefGCA
# 0       4       4
# 1       4       0
# ...

# %%
passes.head()
# Out:
#          Squad  NPl   90s  CmpTot  AttTot  TotCmpRt  TotDist  PrgDist  CmpSh  \
# 0      Arsenal   27  38.0   16110   19512      82.6   300732    87839   6886
# 1  Aston Villa   31  38.0   12521   16026      78.1   244814    86229   5111
# 2    Brentford   29  38.0   11551   15894      72.7   234064    86823   4443
# 3     Brighton   26  38.0   16342   20297      80.5   319634    96944   6439
# 4      Burnley   23  38.0    9508   13895      68.4   199165    82436   4020
#
#    AttSh  ...  AttLng  CmpLngRt  Ast    xA  AmxA   KP  1;3Car  PPA  CrsPA  \
# 0   7676  ...    3307      58.6   41  36.8   4.2  425    1161  348     77
# 1   5870  ...    3329      55.5   42  33.6   8.4  348     934  305     80
# 2   5378  ...    3622      53.2   33  33.0   0.0  305     877  270     84
# 3   7315  ...    3873      60.4   30  29.1   0.9  343    1120  348     83
# 4   4911  ...    3864      48.3   26  27.7  -1.7  273     801  251     90
#
#    ProgPs
# 0    1168
# 1    1109
# 2    1038
# 3    1210
# ...

# %%
possession.head()
# Out:
#          Squad  NPl  Poss  TotTouc  DefPenTouc  Def3rdTouc  Mid3rdTouc  \
# 0      Arsenal   27  53.2    23735        2447        7398       11003
# 1  Aston Villa   31  46.5    20467        2535        7122        9022
# 2    Brentford   29  44.5    20329        2996        7962        8533
# 3     Brighton   26  54.7    24836        2858        8671       10451
# 4      Burnley   23  39.8    18348        2462        6067        8207
#
#    Att3rdTouc  AttPenTouc  LiveTouc  ...  PrgDistCarr  ProgCarr  1;3Carr  CPA  \
# 0        6845        1093     22142  ...        46159      1865      546  205
# 1        5495         897     18691  ...        34655      1366      395  165
# 2        4823         879     18600  ...        29177      1056      317   99
# 3        7194        1009     23162  ...        42192      1614      483  153
# 4        4967         730     16651  ...        22966       908      337   83
#
#    MisCarr  DisCarr  TargRec  SucRec  RecRt  ProgRec
# ...

# %%
shooting.head()
# Out:
#          Squad  NPl   90s  GlsTot  TotSh  TotShTg  SoTgRt  Sh;90  SoT;90  \
# 0      Arsenal   27  38.0      60    580      185    31.9  15.26    4.87
# 1  Aston Villa   31  38.0      50    461      159    34.5  12.13    4.18
# 2    Brentford   29  38.0      46    441      139    31.5  11.61    3.66
# 3     Brighton   26  38.0      40    483      140    29.0  12.71    3.68
# 4      Burnley   23  38.0      32    406      117    28.8  10.68    3.08
#
#    G;Sh  G;SoT  Dist  FK  PK  PKatt    xG  npxG  npxG;Sh  GmxG  npGmxG
# 0  0.09   0.30  17.3  21   5      8  59.9  54.0     0.10   0.1     1.0
# 1  0.10   0.30  17.1  19   3      3  44.0  41.8     0.09   6.0     5.2
# 2  0.09   0.29  15.6  10   6      6  47.8  43.3     0.10  -1.8    -3.3
# 3  0.07   0.26  16.8  15   4      7  46.0  40.7     0.09  -6.0    -4.7
# 4  0.08   0.26  16.4  14   1      2  39.0  37.4     0.09  -7.0    -6.4

# %%
stats.head()
# Out:
#          Squad  NPl   Age  Poss  MP  GlsTot  AstTot  GmPKTot  PKTot  PKattTot  \
# 0      Arsenal   27  24.4  53.2  38      60      41       55      5         8
# 1  Aston Villa   31  26.1  46.5  38      50      42       47      3         3
# 2    Brentford   29  25.4  44.5  38      46      33       40      6         6
# 3     Brighton   26  26.2  54.7  38      40      30       36      4         7
# 4      Burnley   23  28.5  39.8  38      32      26       31      1         2
#
#    ...  GpAmPKPer90  xGTot  npxGTot  xATot  npxGpxA  xGPer90  xAPer90  \
# 0  ...         2.53   59.9     54.0   36.8     90.8     1.58     0.97
# 1  ...         2.34   44.0     41.8   33.6     75.4     1.16     0.88
# 2  ...         1.92   47.8     43.3   33.0     76.2     1.26     0.87
# 3  ...         1.74   46.0     40.7   29.1     69.8     1.21     0.77
# 4  ...         1.50   39.0     37.4   27.7     65.1     1.03     0.73
#
#    xGpxAPer90  npxGPer90  npxGpxAPer90
# ...

# %%
table.head()
# Out:
#    Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts;MP    xG   xGA  \
# 0   1  Manchester City  38  29   6   3  99  26  73   93    2.45  89.0  27.2
# 1   2        Liverpool  38  28   8   2  94  26  68   92    2.42  89.2  34.3
# 2   3          Chelsea  38  21  11   6  76  33  43   74    1.95  67.2  36.0
# 3   4        Tottenham  38  22   5  11  69  40  29   71    1.87  65.1  39.4
# 4   5          Arsenal  38  22   3  13  61  48  13   69    1.82  59.9  47.1
#
#     xGD  xGD;90  Attendance       Top Team Scorer
# 0  61.9    1.63       52774  Kevin De Bruyne - 15
# 1  55.0    1.45       53352    Mohamed Salah - 23
# 2  31.3    0.82       36443      Mason Mount - 11
# 3  25.8    0.68       56523    Son Heung-min - 23
# 4  12.8    0.34       59665      Bukayo Saka - 11

# %% [markdown]
# Looking for empty values

# %%
defensive.isnull()
# Out:
#     Squad    NPl  TotTkl  TotTklW  Def3rdTck  Mid3rdTck  Att3rdTck  \
# 0   False  False   False    False      False      False      False
# 1   False  False   False    False      False      False      False
# 2   False  False   False    False      False      False      False
# 3   False  False   False    False      False      False      False
# 4   False  False   False    False      False      False      False
# 5   False  False   False    False      False      False      False
# 6   False  False   False    False      False      False      False
# 7   False  False   False    False      False      False      False
# 8   False  False   False    False      False      False      False
# 9   False  False   False    False      False      False      False
# 10  False  False   False    False      False      False      False
# 11  False  False   False    False      False      False      False
# 12  False  False   False    False      False      False      False
# ...

# %%
goalkeeping.isnull()
# Out:
#     Squad   # Pl     MP  GATot   GA90   SoTA  Saves  SaveRt      W      D  \
# 0   False  False  False  False  False  False  False   False  False  False
# 1   False  False  False  False  False  False  False   False  False  False
# 2   False  False  False  False  False  False  False   False  False  False
# 3   False  False  False  False  False  False  False   False  False  False
# 4   False  False  False  False  False  False  False   False  False  False
# 5   False  False  False  False  False  False  False   False  False  False
# 6   False  False  False  False  False  False  False   False  False  False
# 7   False  False  False  False  False  False  False   False  False  False
# 8   False  False  False  False  False  False  False   False  False  False
# 9   False  False  False  False  False  False  False   False  False  False
# 10  False  False  False  False  False  False  False   False  False  False
# 11  False  False  False  False  False  False  False   False  False  False
# ...

# %%
goal_shot.isnull()
# Out:
#     Squad    NPl   SCAT  SCA90  PassLiveSCA  PassDeadSCA  DribSCA  ShSCA  \
# 0   False  False  False  False        False        False    False  False
# 1   False  False  False  False        False        False    False  False
# 2   False  False  False  False        False        False    False  False
# 3   False  False  False  False        False        False    False  False
# 4   False  False  False  False        False        False    False  False
# 5   False  False  False  False        False        False    False  False
# 6   False  False  False  False        False        False    False  False
# 7   False  False  False  False        False        False    False  False
# 8   False  False  False  False        False        False    False  False
# 9   False  False  False  False        False        False    False  False
# 10  False  False  False  False        False        False    False  False
# 11  False  False  False  False        False        False    False  False
# ...

# %%
passes.isnull()
# Out:
#     Squad    NPl    90s  CmpTot  AttTot  TotCmpRt  TotDist  PrgDist  CmpSh  \
# 0   False  False  False   False   False     False    False    False  False
# 1   False  False  False   False   False     False    False    False  False
# 2   False  False  False   False   False     False    False    False  False
# 3   False  False  False   False   False     False    False    False  False
# 4   False  False  False   False   False     False    False    False  False
# 5   False  False  False   False   False     False    False    False  False
# 6   False  False  False   False   False     False    False    False  False
# 7   False  False  False   False   False     False    False    False  False
# 8   False  False  False   False   False     False    False    False  False
# 9   False  False  False   False   False     False    False    False  False
# 10  False  False  False   False   False     False    False    False  False
# ...

# %%
possession.isnull()
# Out:
#     Squad    NPl   Poss  TotTouc  DefPenTouc  Def3rdTouc  Mid3rdTouc  \
# 0   False  False  False    False       False       False       False
# 1   False  False  False    False       False       False       False
# 2   False  False  False    False       False       False       False
# 3   False  False  False    False       False       False       False
# 4   False  False  False    False       False       False       False
# 5   False  False  False    False       False       False       False
# 6   False  False  False    False       False       False       False
# 7   False  False  False    False       False       False       False
# 8   False  False  False    False       False       False       False
# 9   False  False  False    False       False       False       False
# 10  False  False  False    False       False       False       False
# 11  False  False  False    False       False       False       False
# 12  False  False  False    False       False       False       False
# ...

# %%
shooting.isnull()
# Out:
#     Squad    NPl    90s  GlsTot  TotSh  TotShTg  SoTgRt  Sh;90  SoT;90   G;Sh  \
# 0   False  False  False   False  False    False   False  False   False  False
# 1   False  False  False   False  False    False   False  False   False  False
# 2   False  False  False   False  False    False   False  False   False  False
# 3   False  False  False   False  False    False   False  False   False  False
# 4   False  False  False   False  False    False   False  False   False  False
# 5   False  False  False   False  False    False   False  False   False  False
# 6   False  False  False   False  False    False   False  False   False  False
# 7   False  False  False   False  False    False   False  False   False  False
# 8   False  False  False   False  False    False   False  False   False  False
# 9   False  False  False   False  False    False   False  False   False  False
# 10  False  False  False   False  False    False   False  False   False  False
# ...

# %%
stats.isnull()
# Out:
#     Squad    NPl    Age   Poss     MP  GlsTot  AstTot  GmPKTot  PKTot  \
# 0   False  False  False  False  False   False   False    False  False
# 1   False  False  False  False  False   False   False    False  False
# 2   False  False  False  False  False   False   False    False  False
# 3   False  False  False  False  False   False   False    False  False
# 4   False  False  False  False  False   False   False    False  False
# 5   False  False  False  False  False   False   False    False  False
# 6   False  False  False  False  False   False   False    False  False
# 7   False  False  False  False  False   False   False    False  False
# 8   False  False  False  False  False   False   False    False  False
# 9   False  False  False  False  False   False   False    False  False
# 10  False  False  False  False  False   False   False    False  False
# 11  False  False  False  False  False   False   False    False  False
# ...

# %%
table.isnull()
# Out:
#        Rk  Squad     MP      W      D      L     GF     GA     GD    Pts  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
stats.isnull().values.any()
# Out:
# False

# %%
stats.isnull().sum().sum()
# Out:
# 0

# %%
import jovian
jovian.commit(project=project_name)
# Out:
# [jovian] Creating a new project "geohotzdata/EPL Analysis"
# [jovian] Committed successfully! https://jovian.ai/geohotzdata/epl-analysis
# 'https://jovian.ai/geohotzdata/epl-analysis'

# %% [markdown]
# Visualization

# %%
fig = plt.plot(defensive.TklpInt) #Tackles & Interceptions

# %%
x = defensive.TotTklW
y = defensive.TotTkl
#plt.plot(x,y)'
plt.figure(figsize=(12,12))
sns.scatterplot(x,y,hue=defensive.Squad)
# Out:
# C:\Users\srini\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotTklW', ylabel='TotTkl'>

# %%
x = goal_shot.DribGCA
y = goal_shot.ShGCA
sns.scatterplot(y,x)
# Out:
# C:\Users\srini\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ShGCA', ylabel='DribGCA'>

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "geohotzdata/epl-analysis" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/geohotzdata/epl-analysis
# 'https://jovian.ai/geohotzdata/epl-analysis'

# %%
x = stats.NPl
y = stats.Age
sns.scatterplot(y,x)
plt.plot(x,y)
# Out:
# C:\Users\srini\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Comparing the age of the players and the Average Age

# %%
x = stats.GlsTot
y = stats.Poss
sns.scatterplot(y,x)
plt.plot(x,y)
# Out:
# C:\Users\srini\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Team Assists v/s Goals

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "geohotzdata/epl-analysis" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/geohotzdata/epl-analysis
# 'https://jovian.ai/geohotzdata/epl-analysis'
